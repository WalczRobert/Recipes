# %%
import re  # For preprocessing
import pandas as pd  # For data handling
from time import time  # To time our operations
from collections import defaultdict  # For word frequency
import en_core_web_sm
import spacy  # For preprocessing

import logging  # Setting up the loggings to monitor gensim
logging.basicConfig(format="%(levelname)s - %(asctime)s: %(message)s", datefmt= '%H:%M:%S', level=logging.INFO)

# %%
df = pd.read_csv('C:\\Users\\rewal\\Downloads\\NLPtask\\Cleaned_Text\\combined.txt')
df.shape
# Out:
# (96383, 1)

# %%
df = df.dropna().reset_index(drop=True)
df.isnull().sum()
# Out:
# primary uses integrated processor precision machine functions primary navigational point display touchscreen allowing input information generation commandcenter display also use display control allows use input buttons basics software display comes standard basic software feature set manual guidance screen mapping isobus functionality connected gps receiver system allows operator drive machine aid gps combined optional autotrac activation vehicle steering kit system automatically guide machine though field documentation used record data tied gps coordinates machines rates yield implement width information recorded machine bus screen mapping uses gps recording source create real time maps field activities operators able see areas applied maps field covered generation commandcenter display integrated machine work monitors monitors used record area data based implement width ground speed display also used machines systems conform implementation level international organization standardization iso purpose iso enable electronic units communicate providing standardized system easy read understand operator use display tractor performance monitor monitor iso compliant implement software updates published stellarsupport john deere software manager utility used download software updates computer software updates transferred usb drive download stored usb drive inserted display complete update properly equipped generation displays updated air display types three different types generation commandcenter displays display runs version processors screen display runs version processors screen display runs either processor depending year made screen display run page structure display screen illustration provided reference actual screens could appear differently due connection optional devices software versions display different look feel previous john deere displays main menu button exists bottom right hand side clock gps communication appear depending screen size screens clock gps communication top right corner screens lower left corner display run page structure display run page legend menu shortcut softkeys next previous run page buttons status center run page menu softkey lists applications installed display machine shortcut softkeys provide quick access frequently used applications functions display select expand button display shortcut softkeys next previous run page softkeys cycle multiple run pages display status center select area indicated important information gps signal strength available data storage display functions highlighted run page configured using layout manager application display run page structure display run page legend menu shortcut softkeys next previous run page buttons status center run page title bar run page selection menu softkey lists applications installed display machine shortcut softkeys provide quick access frequently used applications functions shortcut keys changed better match operations performed next previous run page softkeys cycle multiple run pages display status center select area indicated important information gps signal strength available data storage display functions highlighted run page configured using layout manager application display run page selection page press title bar choose desired run page list available pages available displays menu page menu run page menu run page contains three tabs machine settings tab stores maintenance calibrations settings along machine specific applications applications tab lists available applications machine system tab stores following com port settings date time diagnostics center display sound file manager language units software manager user access wireless settings applications tab page applications tab page applications tab page applications tab contains following applications application availability varies based machine activations autotrac guidance autotrac turn automation calculator controls setup equipment manager fields boundaries flags help iso ...
# dtype: int64

# %% [markdown]
# CLEANING

# %% [markdown]
# We are lemmatizing and removing the stopwords and non-alphabetic characters for each line of dialogue

# %%
nlp = en_core_web_sm.load(disable=['ner', 'parser'])# disabling Named Entity Recognition for speed

def cleaning(doc):
    # Lemmatizes and removes stopwords
    # doc needs to be a spacy Doc object
    txt = [token.lemma_ for token in doc if not token.is_stop]
    # Word2Vec uses context words to learn the vector representation of a target word,
    # if a sentence is only one or two words long,
    # the benefit for the training is very small
    if len(txt) > 2:
        return ' '.join(txt)

# %%
brief_cleaning = (re.sub("[^A-Za-z']+", ' ', str(row)).lower() for row in df)

# %%
t = time()

txt = [cleaning(doc) for doc in nlp.pipe(brief_cleaning, batch_size=5000, n_threads=-1)]

print('Time to clean up everything: {} mins'.format(round((time() - t) / 60, 2)))
# Out:
# Time to clean up everything: 0.05 mins

# %%
df_clean = pd.DataFrame({'clean': txt})
df_clean = df_clean.dropna()
df_clean.shape
# Out:
# (1, 1)

# %%
from gensim.models.phrases import Phrases, Phraser #bigram detection

# %%
sent = [row.split() for row in df_clean['clean']]

# %%
phrases = Phrases(sent, min_count=30, progress_per=10000)
# Out:
# 2020-04-21 17:27:00,069 : INFO : collecting all words and their counts
# 2020-04-21 17:27:00,070 : INFO : PROGRESS: at sentence #0, processed 0 words and 0 word types
# 2020-04-21 17:27:00,142 : INFO : collected 16687 word types from a corpus of 23169 words (unigram + bigrams) and 1 sentences
# 2020-04-21 17:27:00,144 : INFO : using 16687 counts as vocab in Phrases<0 vocab, min_count=30, threshold=10.0, max_vocab_size=40000000>

# %%
bigram = Phraser(phrases)
sentences = bigram[sent] #Transform the corpus based on the bigrams detected
# Out:
# 2020-04-21 17:28:24,860 : INFO : source_vocab length 16687
# 2020-04-21 17:28:25,237 : INFO : Phraser built with 17 phrasegrams

# %%
word_freq = defaultdict(int)
for sent in sentences:
    for i in sent:
        word_freq[i] += 1
len(word_freq)
# Out:
# 2177

# %%
sorted(word_freq, key=word_freq.get, reverse=True)[:10]
# Out:
# ['display',
#  'machine',
#  'datum',
#  'mtg',
#  'work',
#  'valve',
#  'implement',
#  'system',
#  'application',
#  'autotrac']

# %% [markdown]
# Time to Train the model

# %%
import multiprocessing
from gensim.models import Word2Vec

# %%
cores = multiprocessing.cpu_count() # Count the number of cores in a computer

# %% [markdown]
# The parameters:
#
#     min_count = int - Ignores all words with total absolute frequency lower than this - (2, 100)
#
#     window = int - The maximum distance between the current and predicted word within a sentence. E.g. window words on the left and window words on the left of our target - (2, 10)
#
#     size = int - Dimensionality of the feature vectors. - (50, 300)
#
#     sample = float - The threshold for configuring which higher-frequency words are randomly downsampled. Highly influencial. - (0, 1e-5)
#
#     alpha = float - The initial learning rate - (0.01, 0.05)
#
#     min_alpha = float - Learning rate will linearly drop to min_alpha as training progresses. To set it: alpha - (min_alpha * epochs) ~ 0.00
#
#     negative = int - If > 0, negative sampling will be used, the int for negative specifies how many "noise words" should be drown. If set to 0, no negative sampling is used. - (5, 20)
#
#     workers = int - Use these many worker threads to train the model (=faster training with multicore machines)

# %%
w2v_model = Word2Vec(min_count=20,
                     window=2,
                     size=300,
                     sample=6e-5, 
                     alpha=0.03, 
                     min_alpha=0.0007, 
                     negative=20,
                     workers=cores-1)

# %% [markdown]
# Building the Vocabulary Table:
#
# Word2Vec requires us to build the vocabulary table (simply digesting all the words and filtering out the unique words, and doing some basic counts on them):

# %%
t = time()

w2v_model.build_vocab(sentences, progress_per=10000)

print('Time to build vocab: {} mins'.format(round((time() - t) / 60, 2)))
# Out:
# 2020-04-21 17:31:34,020 : INFO : collecting all words and their counts
# 2020-04-21 17:31:34,142 : INFO : PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# 2020-04-21 17:31:34,148 : INFO : collected 2177 word types from a corpus of 22199 raw words and 1 sentences
# 2020-04-21 17:31:34,149 : INFO : Loading a fresh vocabulary
# 2020-04-21 17:31:34,156 : INFO : effective_min_count=20 retains 273 unique words (12% of original 2177, drops 1904)
# 2020-04-21 17:31:34,157 : INFO : effective_min_count=20 leaves 14579 word corpus (65% of original 22199, drops 7620)
# 2020-04-21 17:31:34,163 : INFO : deleting the raw counts dictionary of 2177 items
# 2020-04-21 17:31:34,165 : INFO : sample=6e-05 downsamples 273 most-common words
# 2020-04-21 17:31:34,166 : INFO : downsampling leaves estimated 2011 word corpus (13.8% of prior 14579)
# 2020-04-21 17:31:34,172 : INFO : estimated required memory for 273 words and 300 dimensions: 791700 bytes
# 2020-04-21 17:31:34,173 : INFO : resetting layer weights
# Time to build vocab: 0.0 mins

# %% [markdown]
# Training of the model:
#
# Parameters of the training:
#
#     total_examples = int - Count of sentences;
#     epochs = int - Number of iterations (epochs) over the corpus - [10, 20, 30]

# %%
t = time()

w2v_model.train(sentences, total_examples=w2v_model.corpus_count, epochs=30, report_delay=1)

print('Time to train the model: {} mins'.format(round((time() - t) / 60, 2)))
# Out:
# 2020-04-21 17:32:23,310 : INFO : training model with 3 workers on 273 vocabulary and 300 features, using sg=0 hs=0 sample=6e-05 negative=20 window=2
# 2020-04-21 17:32:23,460 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-04-21 17:32:23,464 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-04-21 17:32:23,491 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-04-21 17:32:23,493 : INFO : EPOCH - 1 : training on 22199 raw words (2082 effective words) took 0.2s, 13124 effective words/s
# 2020-04-21 17:32:23,608 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-04-21 17:32:23,610 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-04-21 17:32:23,628 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-04-21 17:32:23,630 : INFO : EPOCH - 2 : training on 22199 raw words (2015 effective words) took 0.1s, 17304 effective words/s
# 2020-04-21 17:32:23,741 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-04-21 17:32:23,743 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-04-21 17:32:23,766 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-04-21 17:32:23,770 : INFO : EPOCH - 3 : training on 22199 raw words (1964 effective words) took 0.1s, 15638 effective words/s
# 2020-04-21 17:32:23,879 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-04-21 17:32:23,881 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-04-21 17:32:23,897 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-04-21 17:32:23,898 : INFO : EPOCH - 4 : training on 22199 raw words (1972 effective words) took 0.1s, 16933 effective words/s
# 2020-04-21 17:32:24,010 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-04-21 17:32:24,012 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-04-21 17:32:24,031 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-04-21 17:32:24,034 : INFO : EPOCH - 5 : training on 22199 raw words (1970 effective words) took 0.1s, 16418 effective words/s
# 2020-04-21 17:32:24,164 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-04-21 17:32:24,170 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-04-21 17:32:24,182 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-04-21 17:32:24,184 : INFO : EPOCH - 6 : training on 22199 raw words (1965 effective words) took 0.1s, 14859 effective words/s
# 2020-04-21 17:32:24,323 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-04-21 17:32:24,324 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-04-21 17:32:24,346 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-04-21 17:32:24,371 : INFO : EPOCH - 7 : training on 22199 raw words (2018 effective words) took 0.1s, 14134 effective words/s
# 2020-04-21 17:32:24,508 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-04-21 17:32:24,509 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-04-21 17:32:24,535 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-04-21 17:32:24,539 : INFO : EPOCH - 8 : training on 22199 raw words (1954 effective words) took 0.1s, 15330 effective words/s
# 2020-04-21 17:32:24,671 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-04-21 17:32:24,673 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-04-21 17:32:24,694 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-04-21 17:32:24,695 : INFO : EPOCH - 9 : training on 22199 raw words (1958 effective words) took 0.1s, 14018 effective words/s
# 2020-04-21 17:32:24,813 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-04-21 17:32:24,816 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-04-21 17:32:24,834 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-04-21 17:32:24,836 : INFO : EPOCH - 10 : training on 22199 raw words (1955 effective words) took 0.1s, 14716 effective words/s
# 2020-04-21 17:32:24,955 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-04-21 17:32:24,957 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-04-21 17:32:24,978 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-04-21 17:32:24,980 : INFO : EPOCH - 11 : training on 22199 raw words (1967 effective words) took 0.1s, 14750 effective words/s
# 2020-04-21 17:32:25,105 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-04-21 17:32:25,107 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-04-21 17:32:25,127 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-04-21 17:32:25,128 : INFO : EPOCH - 12 : training on 22199 raw words (2022 effective words) took 0.1s, 15128 effective words/s
# 2020-04-21 17:32:25,247 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-04-21 17:32:25,257 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-04-21 17:32:25,272 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-04-21 17:32:25,273 : INFO : EPOCH - 13 : training on 22199 raw words (2062 effective words) took 0.1s, 15778 effective words/s
# 2020-04-21 17:32:25,501 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-04-21 17:32:25,503 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-04-21 17:32:25,521 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-04-21 17:32:25,523 : INFO : EPOCH - 14 : training on 22199 raw words (1968 effective words) took 0.1s, 13810 effective words/s
# 2020-04-21 17:32:25,650 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-04-21 17:32:25,653 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-04-21 17:32:25,673 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-04-21 17:32:25,675 : INFO : EPOCH - 15 : training on 22199 raw words (2016 effective words) took 0.1s, 15453 effective words/s
# 2020-04-21 17:32:25,812 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-04-21 17:32:25,814 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-04-21 17:32:25,837 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-04-21 17:32:25,838 : INFO : EPOCH - 16 : training on 22199 raw words (2033 effective words) took 0.1s, 14483 effective words/s
# 2020-04-21 17:32:25,994 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-04-21 17:32:25,997 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-04-21 17:32:26,015 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-04-21 17:32:26,016 : INFO : EPOCH - 17 : training on 22199 raw words (2024 effective words) took 0.1s, 13925 effective words/s
# 2020-04-21 17:32:26,145 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-04-21 17:32:26,148 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-04-21 17:32:26,167 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-04-21 17:32:26,169 : INFO : EPOCH - 18 : training on 22199 raw words (1991 effective words) took 0.1s, 14890 effective words/s
# 2020-04-21 17:32:26,322 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-04-21 17:32:26,324 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-04-21 17:32:26,345 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-04-21 17:32:26,353 : INFO : EPOCH - 19 : training on 22199 raw words (1988 effective words) took 0.1s, 14337 effective words/s
# 2020-04-21 17:32:26,526 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-04-21 17:32:26,531 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-04-21 17:32:26,549 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-04-21 17:32:26,550 : INFO : EPOCH - 20 : training on 22199 raw words (2035 effective words) took 0.2s, 12271 effective words/s
# 2020-04-21 17:32:26,697 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-04-21 17:32:26,707 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-04-21 17:32:26,722 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-04-21 17:32:26,724 : INFO : EPOCH - 21 : training on 22199 raw words (2057 effective words) took 0.1s, 15103 effective words/s
# 2020-04-21 17:32:26,852 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-04-21 17:32:26,854 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-04-21 17:32:26,874 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-04-21 17:32:26,876 : INFO : EPOCH - 22 : training on 22199 raw words (2074 effective words) took 0.1s, 15975 effective words/s
# 2020-04-21 17:32:27,004 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-04-21 17:32:27,005 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-04-21 17:32:27,025 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-04-21 17:32:27,026 : INFO : EPOCH - 23 : training on 22199 raw words (2087 effective words) took 0.1s, 15855 effective words/s
# 2020-04-21 17:32:27,157 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-04-21 17:32:27,159 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-04-21 17:32:27,182 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-04-21 17:32:27,184 : INFO : EPOCH - 24 : training on 22199 raw words (2081 effective words) took 0.1s, 15571 effective words/s
# 2020-04-21 17:32:27,322 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-04-21 17:32:27,327 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-04-21 17:32:27,343 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-04-21 17:32:27,344 : INFO : EPOCH - 25 : training on 22199 raw words (2004 effective words) took 0.1s, 14330 effective words/s
# 2020-04-21 17:32:27,499 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-04-21 17:32:27,501 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-04-21 17:32:27,521 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-04-21 17:32:27,523 : INFO : EPOCH - 26 : training on 22199 raw words (2064 effective words) took 0.1s, 14341 effective words/s
# 2020-04-21 17:32:27,689 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-04-21 17:32:27,707 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-04-21 17:32:27,715 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-04-21 17:32:27,717 : INFO : EPOCH - 27 : training on 22199 raw words (1971 effective words) took 0.2s, 11389 effective words/s
# 2020-04-21 17:32:27,888 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-04-21 17:32:27,889 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-04-21 17:32:27,909 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-04-21 17:32:27,911 : INFO : EPOCH - 28 : training on 22199 raw words (1971 effective words) took 0.1s, 13333 effective words/s
# 2020-04-21 17:32:28,053 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-04-21 17:32:28,055 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-04-21 17:32:28,077 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-04-21 17:32:28,078 : INFO : EPOCH - 29 : training on 22199 raw words (2044 effective words) took 0.2s, 13624 effective words/s
# 2020-04-21 17:32:28,232 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-04-21 17:32:28,238 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-04-21 17:32:28,253 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-04-21 17:32:28,256 : INFO : EPOCH - 30 : training on 22199 raw words (1944 effective words) took 0.2s, 12229 effective words/s
# 2020-04-21 17:32:28,257 : INFO : training on a 665970 raw words (60256 effective words) took 4.9s, 12181 effective words/s
# Time to train the model: 0.08 mins

# %% [markdown]
# As we do not plan to train the model any further, we are calling init_sims(), which will make the model much more memory-efficient:

# %%
w2v_model.init_sims(replace=True)
# Out:
# 2020-04-21 17:33:35,170 : INFO : precomputing L2-norms of word weight vectors

# %%
w2v_model.wv.most_similar(positive=["autotrac"])
# Out:
# [('turn_automation', 0.9999270439147949),
#  ('guidance', 0.999924898147583),
#  ('implement', 0.999916136264801),
#  ('activation', 0.9999126195907593),
#  ('profile', 0.9999101161956787),
#  ('guidance_line', 0.9999090433120728),
#  ('automation', 0.9999086260795593),
#  ('application', 0.9999067783355713),
#  ('select', 0.9999051690101624),
#  ('tab', 0.9999046325683594)]
